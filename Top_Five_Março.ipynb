# %% [markdown]
# <a href="https://colab.research.google.com/github/rsousadev/Peer-Review/blob/master/Top_Five_Mar%C3%A7o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Top Five Março 2020

# %%
import pandas as pd
import math
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('notas.csv')

# %% [markdown]
# ##Quem participou

# %%
participantes = pd.DataFrame(list(data['ENVIADO POR'].drop_duplicates()))

# %%
participantes
# Out:
#                                                0
# 0                                Mendelson Thom�
# 1                       Lucas Martins dos Santos
# 2                                  Paulo Roberto
# 3                                         Thomas
# 4                              Douglas Pelegrini
# 5                                   Rodrigo Lima
# 6                                  Carolina Rios
# 7   Ana Rog�ria Ventura de Carvalho Paes Ribeiro
# 8                                Priscila Fukuma
# 9                                         Marina
# 10                              WALTER VER�SSIMO
# 11                                Valeria Kessel
# 12                              Jeferson Nicolau
# 13                               Raimundo Junior
# 14                             Ailan Ferro Lopes
# 15                              Alexandre Afonso
# 16                     Leonardo Moreira Carvalho
# 17                              Gustavo Henrique
# ...

# %%
participacao = pd.DataFrame(pd.pivot_table(data, index=data['ENVIADO POR'], aggfunc='size'))

# %% [markdown]
# ## Quantidade de Participação

# %%
participacao
# Out:
#                                               0
# ENVIADO POR
# Ailan Ferro Lopes                             1
# Alexandre Afonso                              1
# Ana Rog�ria Ventura de Carvalho Paes Ribeiro  1
# Andr� Bernardo                                1
# Carolina Rios                                 1
# Douglas Pelegrini                             4
# Erick Felipe Borges                           1
# Guilherme Furlong                             1
# Gustavo Henrique                              1
# Jeferson Nicolau                              2
# Leonardo Moreira Carvalho                     1
# Lucas Martins dos Santos                      1
# Luis Montanez                                 1
# Marina                                        1
# Mendelson Thom�                               5
# Paulo Roberto                                 3
# Priscila Fukuma                               2
# Raimundo Junior                               1
# ...

# %%
data['LEAD'] = data['LEAD'].str.replace(',','.')
data['LEAD'] = data['LEAD'].astype(float)
data['TITULO'] = data['TITULO'].str.replace(',','.')
data['TITULO'] = data['TITULO'].astype(float).round(2)
data['LEAD'] = data['LEAD'].astype(float).round(2)

# %% [markdown]
# ##Nota Média do Titulo

# %%
data['TITULO'].mean()
# Out:
# 2.255

# %% [markdown]
# ##Nota Média Da LEAD

# %%
data['LEAD'].mean()
# Out:
# 2.479166666666667

# %% [markdown]
# ## Nota Máxima Do Titulo

# %%
data['TITULO'].max()
# Out:
# 3.33

# %% [markdown]
# ## Nota Máxima da LEAD

# %%
data['LEAD'].max()
# Out:
# 4.0

# %% [markdown]
# ## Nota Minima LEAD

# %%
data['LEAD'].min()
# Out:
# 1.69

# %% [markdown]
# ##Nota Minima Titulo

# %%
data['TITULO'].min()
# Out:
# 1.0

# %%
data['TITULO'].describe()
# Out:
# count    36.000000
# mean      2.255000
# std       0.543762
# min       1.000000
# 25%       1.860000
# 50%       2.335000
# 75%       2.590000
# max       3.330000
# Name: TITULO, dtype: float64

# %%
data['LEAD'].describe()
# Out:
# count    36.000000
# mean      2.479167
# std       0.484499
# min       1.690000
# 25%       2.000000
# 50%       2.430000
# 75%       2.817500
# max       4.000000
# Name: LEAD, dtype: float64

# %% [markdown]
# ##Nota Média De Sim

# %%
data['SIM'].mean()
# Out:
# 6.555555555555555

# %% [markdown]
# ##Nota Média De Não

# %%
data['NÃO'].mean()
# Out:
# 3.4166666666666665

# %% [markdown]
# ##Melhores Notas De Acordo Com a quantidade de avaliações, tiulo, lead, quantidade de sim e não

# %%
avaliacoes = (data['SIM'] + data['NÃO'])
data['Avaliações'] = pd.Series(data=avaliacoes.round(2))

# %%
data.sort_values(['Avaliações', 'TITULO', 'LEAD', 'SIM', 'NÃO'], ascending=[False, False, False, False, True])
# Out:
#                                          LINK DA LEAD  ... Média
# 28  https://drive.google.com/file/d/1WCfB-sGbNoNyf...  ...  3.16
# 27  https://drive.google.com/file/d/1X9V9RvKNODy0R...  ...  2.58
# 24  https://drive.google.com/file/d/13qKCEYBy08uN0...  ...  2.46
# 29  https://drive.google.com/file/d/1BkOZ0WA0BRnLM...  ...  2.11
# 25  https://drive.google.com/file/d/1D7GZtJKU_nBa8...  ...  2.04
# 26  https://drive.google.com/file/d/1gLpvCHslTMkob...  ...  1.80
# 34  https://drive.google.com/file/d/1Nqg40CTWWuDSU...  ...  3.00
# 30  https://drive.google.com/file/d/1XLidCI01su0mj...  ...  2.50
# 35  https://drive.google.com/file/d/1-em3JYV7Audll...  ...  2.42
# 31  https://drive.google.com/file/d/1JRPVKNIOJACCP...  ...  2.16
# 33  https://drive.google.com/file/d/1v_Z4M5BDsYt8p...  ...  1.84
# 32  https://drive.google.com/file/d/12XD4MoMZcb3t6...  ...  1.75
# 21  https://drive.google.com/file/d/1bkcDKU21z8od0...  ...  3.50
# ...

# %% [markdown]
# ##Maiores Notas De Acordo Com o Titulo

# %%
data.sort_values(['TITULO'], ascending=[False])
# Out:
#                                          LINK DA LEAD  ... Avaliações
# 8   https://drive.google.com/file/d/1qx0XINxeu5AD2...  ...          9
# 28  https://drive.google.com/file/d/1WCfB-sGbNoNyf...  ...         16
# 34  https://drive.google.com/file/d/1Nqg40CTWWuDSU...  ...         14
# 30  https://drive.google.com/file/d/1XLidCI01su0mj...  ...         14
# 21  https://drive.google.com/file/d/1bkcDKU21z8od0...  ...         11
# 13  https://docs.google.com/document/d/1OupN9nNgXt...  ...          8
# 27  https://drive.google.com/file/d/1X9V9RvKNODy0R...  ...         16
# 5   https://docs.google.com/document/d/13xJSF1mOc5...  ...          7
# 2   https://docs.google.com/document/d/1gIOzW9Mwxl...  ...          7
# 20  https://docs.google.com/document/d/1Tvde3q3C9c...  ...          5
# 11  https://docs.google.com/document/d/1ufBD004_r1...  ...          8
# 35  https://drive.google.com/file/d/1-em3JYV7Audll...  ...         14
# ...

# %% [markdown]
# ##Maiores Notas De Acordo Com o LEAD

# %%
data.sort_values(['LEAD'], ascending=[False])
# Out:
#                                          LINK DA LEAD  ... Média
# 21  https://drive.google.com/file/d/1bkcDKU21z8od0...  ...  3.50
# 28  https://drive.google.com/file/d/1WCfB-sGbNoNyf...  ...  3.16
# 2   https://docs.google.com/document/d/1gIOzW9Mwxl...  ...  2.84
# 0   https://drive.google.com/file/d/1nhqIR8C6OiVqb...  ...  2.50
# 9   https://drive.google.com/file/d/1FcFLTZwYyeynV...  ...  2.50
# 23  https://drive.google.com/file/d/1qkKpcdRyFV7P8...  ...  2.75
# 34  https://drive.google.com/file/d/1Nqg40CTWWuDSU...  ...  3.00
# 16  https://docs.google.com/document/d/1qTwCcX8RX8...  ...  2.66
# 20  https://docs.google.com/document/d/1Tvde3q3C9c...  ...  2.77
# 13  https://docs.google.com/document/d/1OupN9nNgXt...  ...  2.78
# 3   https://drive.google.com/open?id=1MAnf-MriQ_Ti...  ...  2.59
# 10  https://docs.google.com/document/d/1WbnNOPCy9h...  ...  2.58
# 5   https://docs.google.com/document/d/13xJSF1mOc5...  ...  2.67
# ...

# %% [markdown]
# ##Média Geral Titulo e Lead

# %%
media = (data['TITULO'] + data['LEAD']) / 2

# %%
data['Média'] = pd.Series(data=media.round(2))

# %% [markdown]
# ##Maiores Notas De Acordo com a Média

# %%
data_media = data.sort_values(['Média'], ascending=[False])

# %%
data_media
# Out:
#                                          LINK DA LEAD  ... Média
# 21  https://drive.google.com/file/d/1bkcDKU21z8od0...  ...  3.50
# 28  https://drive.google.com/file/d/1WCfB-sGbNoNyf...  ...  3.16
# 34  https://drive.google.com/file/d/1Nqg40CTWWuDSU...  ...  3.00
# 8   https://drive.google.com/file/d/1qx0XINxeu5AD2...  ...  2.92
# 2   https://docs.google.com/document/d/1gIOzW9Mwxl...  ...  2.84
# 13  https://docs.google.com/document/d/1OupN9nNgXt...  ...  2.78
# 20  https://docs.google.com/document/d/1Tvde3q3C9c...  ...  2.77
# 23  https://drive.google.com/file/d/1qkKpcdRyFV7P8...  ...  2.75
# 5   https://docs.google.com/document/d/13xJSF1mOc5...  ...  2.67
# 16  https://docs.google.com/document/d/1qTwCcX8RX8...  ...  2.66
# 3   https://drive.google.com/open?id=1MAnf-MriQ_Ti...  ...  2.59
# 27  https://drive.google.com/file/d/1X9V9RvKNODy0R...  ...  2.58
# 10  https://docs.google.com/document/d/1WbnNOPCy9h...  ...  2.58
# ...

# %% [markdown]
# ##Maiores Notas Médias de acordo com a quantidade de avaliações

# %%
data.sort_values(['Avaliações', 'Média'], ascending=[False, False])
# Out:
#                                          LINK DA LEAD  ... Média
# 28  https://drive.google.com/file/d/1WCfB-sGbNoNyf...  ...  3.16
# 27  https://drive.google.com/file/d/1X9V9RvKNODy0R...  ...  2.58
# 24  https://drive.google.com/file/d/13qKCEYBy08uN0...  ...  2.46
# 29  https://drive.google.com/file/d/1BkOZ0WA0BRnLM...  ...  2.11
# 25  https://drive.google.com/file/d/1D7GZtJKU_nBa8...  ...  2.04
# 26  https://drive.google.com/file/d/1gLpvCHslTMkob...  ...  1.80
# 34  https://drive.google.com/file/d/1Nqg40CTWWuDSU...  ...  3.00
# 30  https://drive.google.com/file/d/1XLidCI01su0mj...  ...  2.50
# 35  https://drive.google.com/file/d/1-em3JYV7Audll...  ...  2.42
# 31  https://drive.google.com/file/d/1JRPVKNIOJACCP...  ...  2.16
# 33  https://drive.google.com/file/d/1v_Z4M5BDsYt8p...  ...  1.84
# 32  https://drive.google.com/file/d/12XD4MoMZcb3t6...  ...  1.75
# 21  https://drive.google.com/file/d/1bkcDKU21z8od0...  ...  3.50
# ...

# %% [markdown]
# ## Maiores Notas Médias De Acordo com a quantidade de avaliações e quantidade de sim

# %%
data.sort_values(['Avaliações', 'Média', 'SIM'], ascending=[False, False, False])
# Out:
#                                          LINK DA LEAD  ... Média
# 28  https://drive.google.com/file/d/1WCfB-sGbNoNyf...  ...  3.16
# 27  https://drive.google.com/file/d/1X9V9RvKNODy0R...  ...  2.58
# 24  https://drive.google.com/file/d/13qKCEYBy08uN0...  ...  2.46
# 29  https://drive.google.com/file/d/1BkOZ0WA0BRnLM...  ...  2.11
# 25  https://drive.google.com/file/d/1D7GZtJKU_nBa8...  ...  2.04
# 26  https://drive.google.com/file/d/1gLpvCHslTMkob...  ...  1.80
# 34  https://drive.google.com/file/d/1Nqg40CTWWuDSU...  ...  3.00
# 30  https://drive.google.com/file/d/1XLidCI01su0mj...  ...  2.50
# 35  https://drive.google.com/file/d/1-em3JYV7Audll...  ...  2.42
# 31  https://drive.google.com/file/d/1JRPVKNIOJACCP...  ...  2.16
# 33  https://drive.google.com/file/d/1v_Z4M5BDsYt8p...  ...  1.84
# 32  https://drive.google.com/file/d/12XD4MoMZcb3t6...  ...  1.75
# 21  https://drive.google.com/file/d/1bkcDKU21z8od0...  ...  3.50
# ...

# %% [markdown]
# ##Notas mais baixas, de acordo com a quantidade de avaliações e quantidade de não

# %%
data.sort_values(['Avaliações', 'Média', 'NÃO'], ascending=[False, True, False])
# Out:
#                                          LINK DA LEAD  ... Média
# 26  https://drive.google.com/file/d/1gLpvCHslTMkob...  ...  1.80
# 25  https://drive.google.com/file/d/1D7GZtJKU_nBa8...  ...  2.04
# 29  https://drive.google.com/file/d/1BkOZ0WA0BRnLM...  ...  2.11
# 24  https://drive.google.com/file/d/13qKCEYBy08uN0...  ...  2.46
# 27  https://drive.google.com/file/d/1X9V9RvKNODy0R...  ...  2.58
# 28  https://drive.google.com/file/d/1WCfB-sGbNoNyf...  ...  3.16
# 32  https://drive.google.com/file/d/12XD4MoMZcb3t6...  ...  1.75
# 33  https://drive.google.com/file/d/1v_Z4M5BDsYt8p...  ...  1.84
# 31  https://drive.google.com/file/d/1JRPVKNIOJACCP...  ...  2.16
# 35  https://drive.google.com/file/d/1-em3JYV7Audll...  ...  2.42
# 30  https://drive.google.com/file/d/1XLidCI01su0mj...  ...  2.50
# 34  https://drive.google.com/file/d/1Nqg40CTWWuDSU...  ...  3.00
# 22  https://drive.google.com/file/d/1UehtUvus23V6p...  ...  1.75
# ...

# %% [markdown]
# ## Melhores notas de acordo com a quantidade de avaliações, média, sim e não

# %%
data.sort_values(['Avaliações', 'Média', 'SIM', 'NÃO'], ascending=[False, False, False, True])
# Out:
#                                          LINK DA LEAD  ... Média
# 28  https://drive.google.com/file/d/1WCfB-sGbNoNyf...  ...  3.16
# 27  https://drive.google.com/file/d/1X9V9RvKNODy0R...  ...  2.58
# 24  https://drive.google.com/file/d/13qKCEYBy08uN0...  ...  2.46
# 29  https://drive.google.com/file/d/1BkOZ0WA0BRnLM...  ...  2.11
# 25  https://drive.google.com/file/d/1D7GZtJKU_nBa8...  ...  2.04
# 26  https://drive.google.com/file/d/1gLpvCHslTMkob...  ...  1.80
# 34  https://drive.google.com/file/d/1Nqg40CTWWuDSU...  ...  3.00
# 30  https://drive.google.com/file/d/1XLidCI01su0mj...  ...  2.50
# 35  https://drive.google.com/file/d/1-em3JYV7Audll...  ...  2.42
# 31  https://drive.google.com/file/d/1JRPVKNIOJACCP...  ...  2.16
# 33  https://drive.google.com/file/d/1v_Z4M5BDsYt8p...  ...  1.84
# 32  https://drive.google.com/file/d/12XD4MoMZcb3t6...  ...  1.75
# 21  https://drive.google.com/file/d/1bkcDKU21z8od0...  ...  3.50
# ...

# %% [markdown]
# ##Melhores notas, apenas contando Média, e quantidade de sim como segundo critério.

# %%
data.sort_values(['Média', 'SIM'], ascending=[False, False])
# Out:
#                                          LINK DA LEAD  ... Média
# 21  https://drive.google.com/file/d/1bkcDKU21z8od0...  ...  3.50
# 28  https://drive.google.com/file/d/1WCfB-sGbNoNyf...  ...  3.16
# 34  https://drive.google.com/file/d/1Nqg40CTWWuDSU...  ...  3.00
# 8   https://drive.google.com/file/d/1qx0XINxeu5AD2...  ...  2.92
# 2   https://docs.google.com/document/d/1gIOzW9Mwxl...  ...  2.84
# 13  https://docs.google.com/document/d/1OupN9nNgXt...  ...  2.78
# 20  https://docs.google.com/document/d/1Tvde3q3C9c...  ...  2.77
# 23  https://drive.google.com/file/d/1qkKpcdRyFV7P8...  ...  2.75
# 5   https://docs.google.com/document/d/13xJSF1mOc5...  ...  2.67
# 16  https://docs.google.com/document/d/1qTwCcX8RX8...  ...  2.66
# 3   https://drive.google.com/open?id=1MAnf-MriQ_Ti...  ...  2.59
# 27  https://drive.google.com/file/d/1X9V9RvKNODy0R...  ...  2.58
# 10  https://docs.google.com/document/d/1WbnNOPCy9h...  ...  2.58
# ...

# %%
data_media.to_csv(r'nota_media_sim.csv', index = False)

# %% [markdown]
# ## Avaliações Por Peer Review

# %%
plt.figure(figsize=(22,4))
sns.lineplot(x=data['DATA'], y=data['Avaliações'], data=data, palette='GnBu_d')

# %%
plt.figure(figsize=(22,4))
sns.lineplot(x=data['DATA'], y=data['Média'], data=data, palette='GnBu_d')
